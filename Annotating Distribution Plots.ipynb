# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
url = 'https://docs.google.com/spreadsheets/d/1VMaw2oCn0ABitd-alLAEsEhGS1Je2UFNLu76TKrIH7w/gviz/tq?tqx=out:csv&sheet=Raw_Medical_Data_for_day1'
df = pd.read_csv(url, index_col = 0)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 1    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 2    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 3    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 4    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 5    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 1    Male        0  ...             0.0       1.0      1.0                1.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3  Female        0  ...             0.0       0.0      0.0                0.0
# 4    Male        0  ...             0.0       0.0      0.0                0.0
# 5  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# # Obtain the histogram of Income

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(df["Income"], stat="probability");

# %%
## Calculate the Mean
mean = df["Income"].mean()
mean
# Out:
# 40653.044949999996

# %% [markdown]
# ## Add the line for the mean

# %%
fig, ax  = plt.subplots(figsize=(10,6))
#think about assigning df["Income"] to a variable for easy switch out (variable = df{col})
sns.histplot(df["Income"], stat="probability")
#Putting the actual mean value in axvline so it can show up in the legend
ax.axvline(mean, color="red", label=f"Mean = {mean:,.2f}");
#could use f"{col}"
ax.set_title("Income")
ax.legend();

# %% [markdown]
# # Creating Mean and Median Lines

# %%
col = "Income"
feature = df[col]
mean = feature.mean()
median = feature.median()
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(feature, stat="probability")
ax.axvline(mean, color="red", label = f"Mean = {mean:,.2f}")
ax.axvline(median,ls = "--", color="green", label = f"Median = {median:,.2f}")
ax.set_title(f"{col}")
ax.legend();

# %% [markdown]
# # Highlight a range of values

# %%
col = "Income"
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(feature, stat="probability")
ax.axvline(plus_one_std , color="black", label=f"+1 std {plus_one_std:,.2f}")
ax.axvline(minus_one_std, color="black", label=f"-1 std {minus_one_std:,.2f}")
ax.set_title(f"{col}")
ax.legend();

# %% [markdown]
# # Highlight Space btw 2 lines

# %%
col = 'Income'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
# to have yellow area behind the rest of the plot use "zorder = 0"
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();
